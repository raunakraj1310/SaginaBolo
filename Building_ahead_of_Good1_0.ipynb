# %% [markdown]
# <a href="https://colab.research.google.com/github/raunakraj1310/SaginaBolo/blob/main/Building_ahead_of_Good1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dependencies

# %%
#Clone Dependenies
# 1. Install system audio dependencies
# !apt-get update && apt-get install -y ffmpeg
print("Dependencies for clone installed")
# 2. Install the Coqui TTS package
# !pip install coqui-tts
# 3. Restart the runtime if required by your environment
#Install CBOX Dependencies
# !pip install --force-reinstall torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --extra-index-url https://pytorch.org
# !pip install "numpy>=1.24,<2.3"
# !pip install -q chatterbox-tts
print("Dependencies for TTS installed")
#Install ASR Dependencies
# !pip -q install -U transformers  soundfile gradio huggingface_hub onnxruntime

print("✅ Dependencies installed")
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease [1,578 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ InRelease [3,631 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  Packages [1,869 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu noble InRelease [9,161 B]
# Get:6 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu noble-cran40/ Packages [72.8 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu noble InRelease
# Get:9 https://cli.github.com/packages stable/main amd64 Packages [359 B]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu noble/main all Packages [10.2 MB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu noble InRelease
# Get:14 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu noble/main amd64 Packages [3,005 kB]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [1,801 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [56.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [1,566 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [1,922 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [2,148 kB]
# Get:21 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [1,244 kB]
# Get:22 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1,532 kB]
# Fetched 25.8 MB in 4s (7,195 kB/s)
# Reading package lists... Done
# W: https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:6.1.1-3ubuntu5).
# 0 upgraded, 0 newly installed, 0 to remove and 90 not upgraded.
# Dependencies for clone installed
# Collecting coqui-tts
#   Downloading coqui_tts-0.27.5-py3-none-any.whl.metadata (21 kB)
# Collecting anyascii>=0.3.0 (from coqui-tts)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting coqpit-config<0.3.0,>=0.2.0 (from coqui-tts)
#   Downloading coqpit_config-0.2.5-py3-none-any.whl.metadata (11 kB)
# Collecting coqui-tts-trainer<0.4.0,>=0.3.0 (from coqui-tts)
#   Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (0.8.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts) (2025.12.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (7.5.0)
# Collecting ko-speech-tools>=0.1.0 (from coqui-tts)
#   Downloading ko_speech_tools-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: librosa>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (0.11.0)
# Requirement already satisfied: matplotlib>=3.8.4 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (3.10.0)
# Collecting monotonic-alignment-search>=0.1.0 (from coqui-tts)
#   Downloading monotonic_alignment_search-0.2.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Collecting num2words>=0.5.14 (from coqui-tts)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numba>=0.58.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (0.61.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (2.1.3)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (26.3)
# Collecting pysbd>=0.3.4 (from coqui-tts)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (6.0.3)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (1.16.3)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (0.14.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (4.67.3)
# Requirement already satisfied: transformers>=4.57 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (5.16.1)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.13/dist-packages (from coqui-tts) (4.16.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.13/dist-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.1 in /usr/local/lib/python3.13/dist-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (2.20.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts) (3.14.3)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.13/dist-packages (from inflect>=5.6.0->coqui-tts) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from inflect>=5.6.0->coqui-tts) (4.6.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (3.1.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (1.1.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (1.2.2)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (3.13.0)
# Requirement already satisfied: standard-sunau in /usr/local/lib/python3.13/dist-packages (from librosa>=0.11.0->coqui-tts) (3.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.8.4->coqui-tts) (2.9.0.post0)
# Collecting docopt>=0.6.2 (from num2words>=0.5.14->coqui-tts)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.58.0->coqui-tts) (0.44.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile>=0.12.0->coqui-tts) (2.1.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.57->coqui-tts) (1.29.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.57->coqui-tts) (2025.11.3)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.57->coqui-tts) (0.23.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers>=4.57->coqui-tts) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.57->coqui-tts) (0.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.24.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts) (3.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (3.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (0.28.1)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.0->librosa>=0.11.0->coqui-tts) (3.1.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts) (4.11.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.4->coqui-tts) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->coqui-tts) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (1.83.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.10.3)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (5.29.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (80.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.1.8)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->librosa>=0.11.0->coqui-tts) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from standard-aifc->librosa>=0.11.0->coqui-tts) (0.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.57->coqui-tts) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.57->coqui-tts) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.57->coqui-tts) (0.0.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.57->coqui-tts) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.57->coqui-tts) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.57->coqui-tts) (2.21.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.57->coqui-tts) (0.1.2)
# Downloading coqui_tts-0.27.5-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.8/862.8 kB 16.9 MB/s eta 0:00:00
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 12.9 MB/s eta 0:00:00
# Downloading coqpit_config-0.2.5-py3-none-any.whl (15 kB)
# Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 4.3 MB/s eta 0:00:00
# Downloading ko_speech_tools-0.1.0-py3-none-any.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.3/997.3 kB 18.8 MB/s eta 0:00:00
# Downloading monotonic_alignment_search-0.2.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (639 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.3/639.3 kB 27.7 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 9.9 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 3.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13781 sha256=fcac8a119ab728ff8132d4707bb519cea6d6654db1a166f019cc1c93a3647d6f
#   Stored in directory: /root/.cache/pip/wheels/0b/1d/03/175286677fb5a1341cc3e4755bf8ec0ed08f3329afd67446b0
# Successfully built docopt
# Installing collected packages: docopt, pysbd, num2words, monotonic-alignment-search, ko-speech-tools, coqpit-config, anyascii, coqui-tts-trainer, coqui-tts
# Successfully installed anyascii-0.3.3 coqpit-config-0.2.5 coqui-tts-0.27.5 coqui-tts-trainer-0.3.3 docopt-0.6.2 ko-speech-tools-0.1.0 monotonic-alignment-search-0.2.1 num2words-0.5.14 pysbd-0.3.4
# Looking in indexes: https://pypi.org/simple, https://pytorch.org
# Collecting torch==2.6.0
#   Downloading torch-2.6.0-cp313-cp313-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.21.0
#   Downloading torchvision-0.21.0-cp313-cp313-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio==2.6.0
#   Downloading torchaudio-2.6.0-cp313-cp313-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch==2.6.0)
#   Downloading filelock-4.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch==2.6.0)
#   Downloading typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting networkx (from torch==2.6.0)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch==2.6.0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch==2.6.0)
#   Downloading fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch==2.6.0)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.6.0)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch==2.6.0)
#   Downloading triton-3.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting setuptools (from torch==2.6.0)
#   Downloading setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy==1.13.1 (from torch==2.6.0)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting numpy (from torchvision==0.21.0)
#   Downloading numpy-2.5.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision==0.21.0)
#   Downloading pillow-12.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch==2.6.0)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.6.0)
#   Downloading markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.6.0-cp313-cp313-manylinux1_x86_64.whl (766.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 1.2 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp313-cp313-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 101.0 MB/s eta 0:00:00
# Downloading torchaudio-2.6.0-cp313-cp313-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 75.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 829.7 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 9.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.0 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 131.0 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 6.8 MB/s eta 0:00:00
# Downloading pillow-12.3.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 80.8 MB/s eta 0:00:00
# Downloading typing_extensions-4.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 4.5 MB/s eta 0:00:00
# Downloading filelock-4.0.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 11.9 MB/s eta 0:00:00
# Downloading fsspec-2026.7.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.6/206.6 kB 22.3 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 13.3 MB/s eta 0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.3 MB/s eta 0:00:00
# Downloading numpy-2.5.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 59.0 MB/s eta 0:00:00
# Downloading setuptools-84.0.0-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.2/818.2 kB 55.1 MB/s eta 0:00:00
# Downloading markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 42.3 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, setuptools, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.16.0
#     Uninstalling typing_extensions-4.16.0:
#       Successfully uninstalled typing_extensions-4.16.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.10.2
#     Uninstalling setuptools-80.10.2:
#       Successfully uninstalled setuptools-80.10.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.32.5
#     Uninstalling filelock-3.32.5:
#       Successfully uninstalled filelock-3.32.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.26.0+cu128
#     Uninstalling torchvision-0.26.0+cu128:
#       Successfully uninstalled torchvision-0.26.0+cu128
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.11.0+cu128
#     Uninstalling torchaudio-2.11.0+cu128:
#       Successfully uninstalled torchaudio-2.11.0+cu128
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# datasets 4.8.5 requires fsspec[http]<=2026.2.0,>=2023.1.0, but you have fsspec 2026.7.0 which is incompatible.
# gcsfs 2025.12.0 requires fsspec==2025.12.0, but you have fsspec 2026.7.0 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.5.3 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-4.0.0 fsspec-2026.7.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 numpy-2.5.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-12.3.0 setuptools-84.0.0 sympy-1.13.1 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0 triton-3.2.0 typing-extensions-4.16.0
# Collecting numpy<2.3,>=1.24
#   Downloading numpy-2.2.6-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.5.3
#     Uninstalling numpy-2.5.3:
#       Successfully uninstalled numpy-2.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.8.5 requires fsspec[http]<=2026.2.0,>=2023.1.0, but you have fsspec 2026.7.0 which is incompatible.
# Successfully installed numpy-2.2.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 58.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 120.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 103.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 86.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 122.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.6/470.6 kB 43.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.8.5 requires fsspec[http]<=2026.2.0,>=2023.1.0, but you have fsspec 2026.7.0 which is incompatible.
# google-adk 2.7.1 requires starlette<2,>=1.3.1, but you have starlette 0.52.1 which is incompatible.
# python-fasthtml 0.14.12 requires starlette>=1.0.1, but you have starlette 0.52.1 which is incompatible.
# Dependencies for TTS installed
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 108.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 57.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 86.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 97.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chatterbox-tts 0.1.7 requires gradio==6.8.0, but you have gradio 6.27.0 which is incompatible.
# chatterbox-tts 0.1.7 requires safetensors==0.5.3, but you have safetensors 0.8.0 which is incompatible.
# chatterbox-tts 0.1.7 requires transformers==5.2.0, but you have transformers 5.17.0 which is incompatible.
# datasets 4.8.5 requires fsspec[http]<=2026.2.0,>=2023.1.0, but you have fsspec 2026.7.0 which is incompatible.
# ✅ Dependencies installed

# %%
import os
import gradio as gr
import numpy as np
import torch
import librosa
import sys
import time
import json
import csv
import traceback
from pathlib import Path
from datetime import datetime, timezone
import transformers
import huggingface_hub

# %%
os.environ["HF_HUB_DISABLE_XET"] = "1"
print("Transformers:", transformers.__version__)
print("HF Hub:", huggingface_hub.__version__)
print("Xet disabled:", os.environ["HF_HUB_DISABLE_XET"])
# Out:
# Transformers: 5.17.0
# HF Hub: 1.31.0
# Xet disabled: 1

# %%
# 0. Verify Colab GPU



print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if not torch.cuda.is_available():
    raise RuntimeError(
        "Enable a GPU in Colab: Runtime → Change runtime type → GPU"
    )

print("GPU:", torch.cuda.get_device_name(0))
print(
    f"VRAM: "
    f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB"
)
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# PyTorch: 2.6.0+cu124
# CUDA available: True
# GPU: Tesla T4
# VRAM: 14.56 GB

# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>EAQ0-KUME</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>RaunakRajR</b> (token: <code>oauth-RaunakRajR</code>).<br>This token will be refreshed automatically when it expires.</center>

# %% [markdown]
# # Transcription

# %%
def transcribe(audio):

# Load an audio file
  wav, sr = torchaudio.load(audio)
  wav = torch.mean(wav, dim=0, keepdim=True)

  target_sample_rate = 16000  # Expected sample rate
  if sr != target_sample_rate:
      resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=target_sample_rate)
      wav = resampler(wav)


  # Perform ASR with RNNT decoding
  transcription_rnnt = model(wav, "hi", "rnnt")
  return(transcription_rnnt)

# %% [markdown]
# # IndicTrans2 HF Inference
#
# We provide an example notebook on how to use our IndicTrans2 models which were originally trained with the fairseq to HuggingFace transformers for inference purpose.

# %% [markdown]
# ## Setup
#
# Please run the cells below to install the necessary dependencies.

# %%
# %%capture
# !git clone https://github.com/AI4Bharat/IndicTrans2.git

# %%
# %%capture
# %cd /content/IndicTrans2/huggingface_interface

# %%
# %%capture
# !python3 -m pip install nltk sacremoses pandas regex mock transformers==4.53.2 mosestokenizer
# !python3 -c "import nltk; nltk.download('punkt')"
# !python3 -m pip install bitsandbytes scipy accelerate datasets
# !python3 -m pip install sentencepiece

# !git clone https://github.com/VarunGumma/IndicTransToolkit.git
# %cd IndicTransToolkit
# !python3 -m pip install --editable ./
# %cd ..

# %% [markdown]
# **IMPORTANT : Restart your run-time first and then run the cells below.**

# %% [markdown]
# ## ASR

# %%
import os
import gradio as gr
import numpy as np
import torch
import librosa
import sys
import time
import json
import csv
import traceback
from pathlib import Path
from datetime import datetime, timezone
import transformers
import huggingface_hub

# %%
from transformers import AutoModelForSeq2SeqLM, BitsAndBytesConfig, AutoTokenizer
from IndicTransToolkit.processor import IndicProcessor

BATCH_SIZE = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
quantization = None

# %%
from transformers import AutoModel
import torch, torchaudio

# Load the model
model = AutoModel.from_pretrained("ai4bharat/indic-conformer-600m-multilingual", trust_remote_code=True)
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# model_onnx.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indic-conformer-600m-multilingual:
# - model_onnx.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# Fetching 404 files:   0%|          | 0/404 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# assets/ctc_decoder.onnx:   0%|          | 0.00/23.1M [00:00<?, ?B/s]
# assets/joint_post_net_as.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_bn.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/encoder.onnx:   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# assets/joint_enc.onnx:   0%|          | 0.00/2.63M [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# assets/Constant_1970_attr__value:   0%|          | 0.00/41.0M [00:00<?, ?B/s]
# assets/joint_post_net_brx.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_doi.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_kn.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_gu.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_hi.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_kok.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_ks.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_mai.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_ml.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_mr.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_mni.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_ne.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_or.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_pa.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_sa.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_sat.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_sd.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_ta.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_ur.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_post_net_te.onnx:   0%|          | 0.00/663k [00:00<?, ?B/s]
# assets/joint_pre_net.onnx:   0%|          | 0.00/2.77k [00:00<?, ?B/s]
# assets/joint_pred.onnx:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# language_masks.json: 0.00B [00:00, ?B/s]
# layers.0.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.0.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.0.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.0.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.0.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.1.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.1.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.1.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.1.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.1.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.10.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.10.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.10.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.10.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.11.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.11.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.10.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.11.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.11.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.11.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.12.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.12.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/layers.12.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.12.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.12.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.13.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.13.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.13.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.13.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.14.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.13.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.14.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.14.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.14.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.14.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.15.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.15.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.15.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.15.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.16.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.15.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.16.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.16.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.16.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.17.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.16.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.17.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.17.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.17.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.17.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.18.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.18.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.18.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.18.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.18.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.19.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.19.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.19.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.19.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.19.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.2.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.2.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.2.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.2.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.2.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.20.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.20.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.20.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.20.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.20.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.21.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.21.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.21.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.21.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.22.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.22.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.21.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.22.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.22.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.23.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.22.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.23.conv.pointwise_conv1.we(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.23.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.23.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.23.conv.pointwise_conv2.we(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.3.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.3.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.3.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.3.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.3.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.4.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.4.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.4.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.4.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.5.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.5.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.4.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.5.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/layers.6.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.5.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.5.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.6.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.6.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.6.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# assets/layers.7.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/layers.7.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.6.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.7.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# layers.7.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.7.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.8.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.8.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/layers.8.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# layers.8.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.8.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.9.conv.pointwise_conv1.bias:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# assets/layers.9.conv.pointwise_conv1.wei(…):   0%|          | 0.00/8.39M [00:00<?, ?B/s]
# assets/layers.9.conv.pointwise_conv2.wei(…):   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# layers.9.feed_forward1.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# layers.9.feed_forward2.linear1.bias:   0%|          | 0.00/16.4k [00:00<?, ?B/s]
# onnx__Conv_7995:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_7998:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8004:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8001:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8007:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8010:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8016:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8013:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8022:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8019:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8028:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8031:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8025:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8034:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8037:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8040:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8043:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8046:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8052:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8049:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8058:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8055:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8064:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# onnx__Conv_8061:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# assets/onnx__MatMul_8067:   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# assets/onnx__MatMul_8085:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8083:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8084:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8185:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8095:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8097:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8096:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8191:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8192:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8193:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8194:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8195:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8205:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8206:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8207:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8223:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8229:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8230:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8231:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8232:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8233:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8243:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8244:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8245:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8261:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8267:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8268:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8269:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8281:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8271:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8282:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8270:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8283:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8299:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8305:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8306:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8307:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8308:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8309:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8319:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8320:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8321:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8337:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8343:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8344:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8345:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8357:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8347:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8346:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8358:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8359:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8375:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8381:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8382:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8383:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8385:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8384:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8395:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8396:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8397:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8419:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8413:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8422:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8420:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8433:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8421:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8423:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8434:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8435:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8451:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8457:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8458:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8459:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8460:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8471:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8461:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8473:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8472:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8489:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8495:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8496:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8497:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8498:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8499:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8509:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8510:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8511:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8527:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8533:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8534:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8535:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8537:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8536:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8547:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8548:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8549:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8565:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8572:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8573:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8571:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8574:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8575:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8586:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8585:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8587:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8603:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8609:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8610:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8612:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8611:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8623:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8624:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8613:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8625:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8641:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8648:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8649:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8647:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8650:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8651:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8661:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8662:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8663:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8679:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8685:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8686:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8687:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8688:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8689:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8700:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8699:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8701:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8717:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8723:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8724:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8726:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8725:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8727:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8737:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8738:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8739:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8755:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8761:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8762:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8763:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8765:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8764:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8776:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8775:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8777:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8793:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8799:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8800:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8801:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8813:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8803:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8814:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8802:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8815:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8838:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8831:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8837:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8840:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8839:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8841:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8852:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8851:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8853:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8869:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8875:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8876:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8878:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8877:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8879:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8890:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8889:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8891:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8907:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8913:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8914:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8915:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8916:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8917:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8927:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8928:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8929:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8951:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8952:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8953:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8945:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8954:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8955:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8965:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8966:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8967:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8983:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8989:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8990:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8991:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_8993:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_8992:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9003:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9005:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9004:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9021:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9027:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9028:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9029:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9030:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9031:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9043:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9041:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9042:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9059:   0%|          | 0.00/4.19M [00:00<?, ?B/s]
# assets/onnx__MatMul_9065:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/onnx__MatMul_9066:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# assets/pre_encode.conv.6.weight:   0%|          | 0.00/262k [00:00<?, ?B/s]
# assets/pre_encode.conv.3.weight:   0%|          | 0.00/262k [00:00<?, ?B/s]
# pre_encode.conv.0.weight:   0%|          | 0.00/9.22k [00:00<?, ?B/s]
# pre_encode.conv.2.weight:   0%|          | 0.00/9.22k [00:00<?, ?B/s]
# pre_encode.conv.5.weight:   0%|          | 0.00/9.22k [00:00<?, ?B/s]
# preprocessor.ts:   0%|          | 0.00/91.7k [00:00<?, ?B/s]
# assets/rnnt_decoder.onnx:   0%|          | 0.00/40.7M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# model_ts.py: 0.00B [00:00, ?B/s]
# model_onnx_1b_batched_rnnt.py: 0.00B [00:00, ?B/s]
# Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# /usr/local/lib/python3.13/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:197: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(

# %%
def transcribe(audio):

# Load an audio file
  wav, sr = torchaudio.load(audio)
  wav = torch.mean(wav, dim=0, keepdim=True)

  target_sample_rate = 16000  # Expected sample rate
  if sr != target_sample_rate:
      resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=target_sample_rate)
      wav = resampler(wav)


  # Perform ASR with RNNT decoding
  transcription_rnnt = model(wav, "hi", "rnnt")
  return(transcription_rnnt)

# %%
def initialize_model_and_tokenizer(ckpt_dir, quantization):
    if quantization == "4-bit":
        qconfig = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.bfloat16,
        )
    elif quantization == "8-bit":
        qconfig = BitsAndBytesConfig(
            load_in_8bit=True,
            bnb_8bit_use_double_quant=True,
            bnb_8bit_compute_dtype=torch.bfloat16,
        )
    else:
        qconfig = None

    tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, trust_remote_code=True)
    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        low_cpu_mem_usage=True,
        quantization_config=qconfig,
    )

    if qconfig == None:
        model = model.to(DEVICE)
        if DEVICE == "cuda":
            model.half()

    model.eval()

    return tokenizer, model


def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    translations = []
    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        # Preprocess the batch and extract entity mappings
        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        # Tokenize the batch and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        # Decode the generated tokens into text
        generated_tokens = tokenizer.batch_decode(
            generated_tokens,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=True,
        )

        # Postprocess the translations, including entity replacement
        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %% [markdown]
# # Translation

# %%
indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(indic_en_ckpt_dir, quantization)

ip = IndicProcessor(inference=True)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json: 0.00B [00:00, ?B/s]
# dict.TGT.json: 0.00B [00:00, ?B/s]
# model.SRC:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/759k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/4.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
def initialize_model_and_tokenizer(ckpt_dir, quantization):
    if quantization == "4-bit":
        qconfig = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.bfloat16,
        )
    elif quantization == "8-bit":
        qconfig = BitsAndBytesConfig(
            load_in_8bit=True,
            bnb_8bit_use_double_quant=True,
            bnb_8bit_compute_dtype=torch.bfloat16,
        )
    else:
        qconfig = None

    tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, trust_remote_code=True)
    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        low_cpu_mem_usage=True,
        quantization_config=qconfig,
    )

    if qconfig == None:
        model = model.to(DEVICE)
        if DEVICE == "cuda":
            model.half()

    model.eval()

    return tokenizer, model


def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    translations = []
    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        # Preprocess the batch and extract entity mappings
        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        # Tokenize the batch and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        # Decode the generated tokens into text
        generated_tokens = tokenizer.batch_decode(
            generated_tokens,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=True,
        )

        # Postprocess the translations, including entity replacement
        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %%
def translate(transcript,src_lang="hin_Deva", tgt_lang="eng_Latn"):
  en_translations = batch_translate([transcript], src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip)
  print(f"\n{src_lang} - {tgt_lang}")
  return (en_translations)
  # for input_sentence, translation in zip([transcript], en_translations):
  #     print(f"{src_lang}: {input_sentence}")
  #     print(f"{tgt_lang}: {translation}")

# %%
text="""
उस्ताद राशिद ख़ान को एक संगीत-प्रेमी कैसे याद कर सकता है? इस पर ठहरता हूँ तो कुछ तस्वीरें ज़ेहन में आती हैं। ‘राग यमन’, ‘मारवा’, ‘सोहनी’, ‘मेघ’ और ‘ललित’ जैसे गंभीर ख़याल गाने वाले सिद्ध गायक—राशिद ख़ान। जहाँ भारतीय शास्त्रीय संगीत का बेहद सधा हुआ अनुशासन मौजूद है। जैसे एक समर्पित साधक अपने साधना में लीन हो। उप शास्त्रीय संगीत ‘ठुमरी’, पूर्वी, ‘टप्पे’ और ‘तराना’ इत्यादि गाने वाले— राशिद ख़ान। जहाँ एक आत्मीय खिलंदड़ापन और नोक-झोंक मौजूद हो। सभी संगतकारों को जगह देता हुआ, संवादी और लोकतांत्रिक— राशिद ख़ान। फ़िल्मी संगीत, जैज और कोक स्टूडियो जैसे युवाओं में लोकप्रिय गीत गाने वाले— राशिद ख़ान। एक परंपराबद्ध आधुनिक। जिसके पास कुछ नई और लोकप्रिय चीज़ों के लिए भी अवकाश है। यह अवकाश कुछ उस क़िस्म का है जहाँ नई पीढ़ी से एक ऐसा संवाद की कोई सूरत निकले। यह कुछ-कुछ सुनने की तैयारी कराने जैसा हो या एक कोशिश कि इस रास्ते कुछ नए श्रोताओं को जोड़ा जा सके। संकटमोचन मंदिर के परिसर में टहलते हुए अपने विचार में मग्न एक आस्तिक इंसान। अपने पुत्र को संकटमोचन मंदिर में संकटमोचन के सामने सजदा करने के लिए उत्साहित करता हुआ एक आत्मीय पिता। बनारस में गंगा घाट पर भीड़ से अपने को बचा कर टहलते हुए एक आम मनुष्य और संकटमोचन मंदिर में कार्यक्रम से पहले सुरमंडल मिलाते और कार्यक्रम के बाद अपने मुरीदों से मिलते हुए— राशिद ख़ान। ये वे छवियाँ हैं जिनसे मुझे राशिद ख़ान की याद आती है।
कला में छप्पन वर्ष की उम्र कोई बहुत बड़ी उम्र नहीं मानी जाती। यह कला के पकने की उम्र होती है। कला में निखार आने में एक लंबा वक़्त लगता है। यह राशिद ख़ान साहेब की ख़ुशनसीबी थी कि उन्हें कला जगत में वह पहचान और प्रसिद्धि दोनों मिली जिसके वह सबल हकदार थे। भारत रत्न पंडित भीमसेन जोशी ने राशिद ख़ान को ‘भारतीय शास्त्रीय संगीत का भविष्य’ कहा था।

‘आश्वस्ति’ कुछ अजीब शै है। मृत्यु अक्सर वह छोड़ जाती है, जिसमें हम जीवन के चिह्नों को तलाशते हैं। किंचित भारतीय श्रोताओं की यह बदनसीबी ही कही जाएगी कि अक्सर हमारे भविष्य को बहुत कम समय मिलता है। हम ऐसे त्रासद और हतभाग्य समय में जीने को विवश हैं, जहाँ जेनुइन प्रतिभाएँ उँगलियों पर गिनी जा सकती हैं। यह ऐसा समय है जहाँ कम मनुष्यों की भरमार है। बौनों और आत्ममुग्धों की संख्या हर क्षेत्र में बढती गई है। उस्ताद राशिद ख़ान के जाने से जो रिक्ति हुई है, इसकी भरपाई अब दूर तक संभव प्रतीत नहीं होती दिख रही है।
उस्ताद राशिद ख़ान रामपुर सहसवान घराने के ध्वजवाहक कलाकार। एक कलाकार की तैयारी और प्रस्तुति को अक्सर एक श्रोता समझ नहीं पाता। उसे एक उत्पाद के मानिंद एक तैयार चीज़ मिलती है। मेरा भी उस्ताद राशिद ख़ान से कुछ ऐसा ही संबंध रहा है—उत्पादक और भोक्ता का, किंतु संबंध चाहे जैसा हो एक समय के बाद उससे मोह होना स्वभाविक मानवीय गुण है। हमारी कल्पनाओं में भी यह रिक्ति कहीं नहीं थी। पिछले दिनों जब वह बीमार हुए तो यह उम्मीद थी कि उनके जीवन की यह मध्य-लय सम पर आकर उनकी ख़याल गायकी की ही तरह द्रुत में आ जाएगी, लेकिन यह ‘पुनः सवेरा एक और फेरा है जी का’ ही साबित हुआ। उन्होंने मध्य-लय के सम को ही अपना अंतिम सम माना।

"""
egtrans=translate(text,"hin_Deva", "eng_Latn")
egtrans
# Out:
# hin_Deva - eng_Latn
# ["How can a music-lover remember Ustad Rashid Khan? If I stop here, a few photographs come to mind. Rashid Khan, the accomplished singer who sang serious songs like'Raag Yaman ','Marwa ','Sohni ','Megh'and'Lalit '. Rashid Khan, who has a very refined discipline of Indian classical music. Like a dedicated seeker absorbed in his sadhana. Rashid Khan, who sang sub-classical music like'Thumri ','Purvi ','Tappe'and'Tarana '. Rashid Khan, who has an intimate flair and flamboyance. Giving space to all the accompanists, conversational and democratic. Rashid Khan, who sang popular songs among the youth like film music, jazz and coke studios. Rashid Khan, a traditional modernist. Who has something new and popular to offer."]

# %%
print(egtrans)
# Out:
# ["How can a music-lover remember Ustad Rashid Khan? If I stop here, a few photographs come to mind. Rashid Khan, the accomplished singer who sang serious songs like'Raag Yaman ','Marwa ','Sohni ','Megh'and'Lalit '. Rashid Khan, who has a very refined discipline of Indian classical music. Like a dedicated seeker absorbed in his sadhana. Rashid Khan, who sang sub-classical music like'Thumri ','Purvi ','Tappe'and'Tarana '. Rashid Khan, who has an intimate flair and flamboyance. Giving space to all the accompanists, conversational and democratic. Rashid Khan, who sang popular songs among the youth like film music, jazz and coke studios. Rashid Khan, a traditional modernist. Who has something new and popular to offer."]

# %%
# src_lang, tgt_lang = "hin_Deva", "eng_Latn"
# transcript=transcribe("/content/OSR_in_000_0063_8k.wav")
# translate(transcript,"hin_Deva", "eng_Latn")

# %% [markdown]
# # Implementation

# %%
def live(audio):
  transcripts=transcribe(audio)
  translate(transcripts,src_lang, tgt_lang)

# %% [markdown]
# # Record

# %%
import gradio as gr
import numpy as np
import torch
import torchaudio
from transformers import AutoModel


model.eval()
# Out:
# IndicASRModel()

# %%
model = model.to(DEVICE)
model.eval()

print("Model loaded.")
print("Device:", DEVICE)
# Out:
# Model loaded.
# Device: cuda

# %%
import gradio as gr
print("Gradio version:", gr.__version__)
# Out:
# Gradio version: 6.27.0

# %%
def transcribe(audio):
    if audio is None:
        return ""

    # Gradio may provide (sample_rate, numpy_array)
    sr, y = audio

    # Convert stereo -> mono
    if y.ndim > 1:
        y = y.mean(axis=1)

    # Convert to float32
    y = y.astype(np.float32)

    # Avoid division by zero
    if np.max(np.abs(y)) > 0:
        y = y / np.max(np.abs(y))

    # Convert numpy -> torch
    wav = torch.from_numpy(y).unsqueeze(0)

    # Resample to 16 kHz
    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        wav = resampler(wav)

    # Move to GPU
    wav = wav.to(DEVICE)

    # Indic-Conformer RNNT decoding
    with torch.no_grad():
        transcription = model(wav, "hi", "rnnt")

    return transcription

# %% [markdown]
# # Successful

# %%
import os
import base64
import torch
import torchaudio
import gradio as gr

from IPython.display import Javascript, display
from google.colab.output import eval_js


# ---------------------------------------------------------
# 1. Browser microphone recorder
# ---------------------------------------------------------

def record_from_browser(seconds=5):
    js = Javascript("""
    async function recordAudio(seconds) {

        const stream = await navigator.mediaDevices.getUserMedia({
            audio: true
        });

        const recorder = new MediaRecorder(stream);
        const chunks = [];

        recorder.ondataavailable = event => {
            if (event.data.size > 0) {
                chunks.push(event.data);
            }
        };

        recorder.start();

        await new Promise(resolve =>
            setTimeout(resolve, seconds * 1000)
        );

        recorder.stop();

        await new Promise(resolve => {
            recorder.onstop = resolve;
        });

        stream.getTracks().forEach(track => track.stop());

        const blob = new Blob(chunks, {
            type: recorder.mimeType
        });

        const reader = new FileReader();

        return await new Promise(resolve => {
            reader.onloadend = () => resolve(reader.result);
            reader.readAsDataURL(blob);
        });
    }

    recordAudio
    """)

    display(js)

    data = eval_js(f"recordAudio({seconds})")

    audio_bytes = base64.b64decode(data.split(",")[1])

    webm_path = "/content/current_recording.webm"

    with open(webm_path, "wb") as f:
        f.write(audio_bytes)

    return webm_path


# ---------------------------------------------------------
# 2. Convert browser recording to 16 kHz mono WAV
# ---------------------------------------------------------

def convert_to_wav(webm_path):

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)

    # Stereo -> mono
    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    # Resample to 16 kHz
    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    torchaudio.save(
        wav_path,
        waveform,
        16000
    )

    return wav_path


# ---------------------------------------------------------

# %%
def record_and_transcribe(seconds):

    print("\n🎤 Recording...")

    webm_path = record_from_browser(seconds)

    print("Recorded:", webm_path)
    print("Size:", os.path.getsize(webm_path), "bytes")

    wav_path = convert_to_wav(webm_path)

    print("Converted:", wav_path)

    # ASR + Translation
    final_hindi, final_english = transcribe_wav(wav_path)

    return final_hindi, final_english, wav_path

# %%
def transcribe_wav(wav_path, chunk_seconds=8):

    print("\n🎧 Loading:", wav_path)

    waveform, sr = torchaudio.load(wav_path)

    # Stereo → mono
    if waveform.shape[0] > 1:
        waveform = torch.mean(
            waveform,
            dim=0,
            keepdim=True
        )

    # Resample → 16 kHz
    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    sr = 16000

    total_samples = waveform.shape[1]
    total_seconds = total_samples / sr

    print(f"🎵 Total duration: {total_seconds:.2f} seconds")

    chunk_samples = int(chunk_seconds * sr)

    hindi_chunks = []
    english_chunks = []

    # ------------------------------------------------
    # Process every chunk
    # ------------------------------------------------

    for start in range(0, total_samples, chunk_samples):

        end = min(
            start + chunk_samples,
            total_samples
        )

        chunk = waveform[:, start:end]

        print(
            f"\n🧩 Processing "
            f"{start/sr:.1f}s → {end/sr:.1f}s"
        )

        if chunk.shape[1] < int(0.3 * sr):
            continue

        # --------------------------------------------
        # Hindi ASR
        # --------------------------------------------

        hindi_text = model(
            chunk,
            "hi",
            "rnnt"
        )

        hindi_text = str(hindi_text).strip()

        print("🇮🇳 Hindi:", hindi_text)

        # If ASR found nothing, don't translate
        if not hindi_text:
            print("⏭️ No speech detected — skipping translation")
            continue

        hindi_chunks.append(hindi_text)

        # --------------------------------------------
        # Hindi → English
        # --------------------------------------------

        english_text = translate(
            hindi_text,
            src_lang="hin_Deva",
            tgt_lang="eng_Latn"
        )

        # batch_translate may return a list
        if isinstance(english_text, list):
            english_text = english_text[0]

        english_text = str(english_text).strip()

        print("🇬🇧 English:", english_text)

        english_chunks.append(english_text)

    # ------------------------------------------------
    # Combine final results
    # ------------------------------------------------

    final_hindi = " ".join(hindi_chunks)
    final_english = " ".join(english_chunks)

    print("\n==============================")
    print("🇮🇳 FINAL HINDI:")
    print(final_hindi)

    print("\n🇬🇧 FINAL ENGLISH:")
    print(final_english)

    print("==============================")

    return final_hindi, final_english

# %%
def record_and_transcribe(seconds):

    print("\n🎤 Recording...")

    webm_path = record_from_browser(seconds)

    print("Recorded:", webm_path)
    print("Size:", os.path.getsize(webm_path), "bytes")

    wav_path = convert_to_wav(webm_path)

    print("Converted:", wav_path)

    # ASR + Translation
    final_hindi, final_english = transcribe_wav(wav_path)

    return final_hindi, final_english, wav_path

# %%
with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎤 Hindi Speech → English Translation
        """
    )

    duration = gr.Slider(
        minimum=2,
        maximum=60,
        value=10,
        step=1,
        label="Recording duration (seconds)"
    )

    record_button = gr.Button("🎙️ Record Hindi")

    transcription = gr.Textbox(
        label="🇮🇳 Hindi Transcription",
        lines=6
    )

    translation = gr.Textbox(
        label="🇬🇧 English Translation",
        lines=6
    )

    recorded_audio = gr.Audio(
        label="Recorded Audio",
        type="filepath"
    )

    record_button.click(
        fn=record_and_transcribe,
        inputs=duration,
        outputs=[
            transcription,
            translation,
            recorded_audio
        ]
    )

# demo.launch(debug=True)

# %% [markdown]
# # Test for Live Translation

# %% [markdown]
# ## Test#0
# Useful: After first silence it never listened!!!I want it that after silence when speech is detected it recsumes its older task.

# %%
def record_from_browser_vad(silence_duration=2.5, calibration_ms=1000, max_seconds=30, margin=0.015):
    js = Javascript("""
    async function recordAudioVAD(silenceDuration, calibrationMs, maxSeconds, margin) {
        const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
        const audioContext = new AudioContext();
        const source = audioContext.createMediaStreamSource(stream);
        const analyser = audioContext.createAnalyser();
        analyser.fftSize = 2048;
        source.connect(analyser);
        const dataArray = new Uint8Array(analyser.fftSize);

        function getRMS() {
            analyser.getByteTimeDomainData(dataArray);
            let sum = 0;
            for (let i = 0; i < dataArray.length; i++) {
                const v = (dataArray[i] - 128) / 128;
                sum += v * v;
            }
            return Math.sqrt(sum / dataArray.length);
        }

        // ---- Calibrate baseline room noise BEFORE recording starts ----
        const calibSamples = [];
        const calibStart = Date.now();
        while (Date.now() - calibStart < calibrationMs) {
            calibSamples.push(getRMS());
            await new Promise(r => setTimeout(r, 50));
        }
        const baseline = calibSamples.reduce((a, b) => a + b, 0) / calibSamples.length;
        const threshold = baseline + margin;
        console.log("Baseline RMS:", baseline, "Threshold:", threshold);

        // ---- Start actual recording ----
        const recorder = new MediaRecorder(stream);
        const chunks = [];
        recorder.ondataavailable = e => { if (e.data.size > 0) chunks.push(e.data); };
        recorder.start();

        const startTime = Date.now();
        let silenceStart = Date.now();

        return await new Promise(resolve => {
            function tick() {
                const rms = getRMS();
                const elapsed = (Date.now() - startTime) / 1000;

                if (rms > threshold) {
                    silenceStart = null;
                } else {
                    if (silenceStart === null) silenceStart = Date.now();
                    if ((Date.now() - silenceStart) / 1000 > silenceDuration) {
                        recorder.stop();
                        return;
                    }
                }

                if (elapsed > maxSeconds) { recorder.stop(); return; }
                requestAnimationFrame(tick);
            }

            recorder.onstop = () => {
                stream.getTracks().forEach(t => t.stop());
                audioContext.close();
                const blob = new Blob(chunks, { type: recorder.mimeType });
                const reader = new FileReader();
                reader.onloadend = () => resolve(reader.result);
                reader.readAsDataURL(blob);
            };

            tick();
        });
    }
    recordAudioVAD
    """)

    display(js)

    data = eval_js(f"recordAudioVAD({silence_duration}, {calibration_ms}, {max_seconds}, {margin})")

    audio_bytes = base64.b64decode(data.split(",")[1])

    webm_path = "/content/current_recording.webm"

    with open(webm_path, "wb") as f:
        f.write(audio_bytes)

    return webm_path

# %%
def convert_to_wav(webm_path):

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    torchaudio.save(
        wav_path,
        waveform,
        16000
    )

    return wav_path

# %%
def convert_to_wav(webm_path):

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    torchaudio.save(
        wav_path,
        waveform,
        16000
    )

    return wav_path

# %%
def transcribe_wav(wav_path):

    waveform, sr = torchaudio.load(wav_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    sr = 16000

    # Too short to contain real speech
    if waveform.shape[1] < int(0.3 * sr):
        return "", ""

    # --------------------------------------------
    # Hindi ASR
    # --------------------------------------------
    hindi_text = model(waveform, "hi", "rnnt")
    hindi_text = str(hindi_text).strip()

    print("🇮🇳 Hindi:", hindi_text)

    if not hindi_text:
        print("⏭️ No speech detected — skipping translation")
        return "", ""

    # --------------------------------------------
    # Hindi → English
    # --------------------------------------------
    english_text = translate(
        hindi_text,
        src_lang="hin_Deva",
        tgt_lang="eng_Latn"
    )

    if isinstance(english_text, list):
        english_text = english_text[0]

    english_text = str(english_text).strip()

    print("🇬🇧 English:", english_text)

    return hindi_text, english_text

# %%
# Shared global flag — this is what Stop actually mutates
recording_control = {"active": False}


def continuous_record_and_transcribe():

    hindi_history = ""
    english_history = ""

    while recording_control["active"]:

        print("\n🎤 Listening for a segment...")

        webm_path = record_from_browser_vad(
            silence_duration=2.5,
            calibration_ms=1000,
            max_seconds=30,
            margin=0.015
        )

        print("Recorded:", webm_path)
        print("Size:", os.path.getsize(webm_path), "bytes")

        wav_path = convert_to_wav(webm_path)
        print("Converted:", wav_path)

        hindi_text, english_text = transcribe_wav(wav_path)

        if hindi_text:
            hindi_history += hindi_text + "\n"
            english_history += english_text + "\n"
            yield hindi_history, english_history, wav_path
        else:
            # Pure silence segment — nothing to show, just loop again
            print("(silence — no update)")

    print("🛑 Stopped listening.")

# %%
def start_flag():
    recording_control["active"] = True

def stop_flag():
    recording_control["active"] = False


with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎤 Hindi Speech → English Translation (continuous)
        Speak, pause for 2.5s of silence to end a segment, and it auto-translates.
        Click Start to begin, Stop to end.
        """
    )

    with gr.Row():
        start_button = gr.Button("▶️ Start Listening")
        stop_button = gr.Button("⏹️ Stop")

    transcription = gr.Textbox(
        label="🇮🇳 Hindi Transcript",
        lines=10
    )

    translation = gr.Textbox(
        label="🇬🇧 English Translation",
        lines=10
    )

    recorded_audio = gr.Audio(
        label="Last Segment",
        type="filepath"
    )

    start_button.click(
        fn=start_flag,
        inputs=None,
        outputs=None
    ).then(
        fn=continuous_record_and_transcribe,
        inputs=None,
        outputs=[transcription, translation, recorded_audio]
    )

    stop_button.click(
        fn=stop_flag,
        inputs=None,
        outputs=None
    )

# demo.launch(debug=True)

# %% [markdown]
# ## Test#1

# %%
def init_microphone():
    js = Javascript("""
    window.micReady = false;

    async function initMic() {
        if (window.micStream) {
            // already initialized, don't re-request
            window.micReady = true;
            return "already_ready";
        }

        const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
        const audioContext = new AudioContext();
        await audioContext.resume();   // guard against 'suspended' state

        const source = audioContext.createMediaStreamSource(stream);
        const analyser = audioContext.createAnalyser();
        analyser.fftSize = 2048;
        source.connect(analyser);

        window.micStream = stream;
        window.micAudioContext = audioContext;
        window.micAnalyser = analyser;
        window.micDataArray = new Uint8Array(analyser.fftSize);
        window.micReady = true;

        console.log("Mic initialized once, persistent.");
        return "ready";
    }
    initMic
    """)
    display(js)
    result = eval_js("initMic()")
    print("Mic init:", result)


def cleanup_microphone():
    js = Javascript("""
    function cleanupMic() {
        if (window.micStream) {
            window.micStream.getTracks().forEach(t => t.stop());
        }
        if (window.micAudioContext) {
            window.micAudioContext.close();
        }
        window.micStream = null;
        window.micAudioContext = null;
        window.micAnalyser = null;
        window.micReady = false;
        console.log("Mic released.");
        return "cleaned";
    }
    cleanupMic
    """)
    display(js)
    result = eval_js("cleanupMic()")
    print("Mic cleanup:", result)

# %%
def record_from_browser_vad(silence_duration=2.5, calibration_ms=1000, max_seconds=30, margin=0.015):
    js = Javascript("""
    async function recordSegment(silenceDuration, calibrationMs, maxSeconds, margin) {
        if (!window.micReady) {
            throw new Error("Mic not initialized — call initMic() first");
        }

        const analyser = window.micAnalyser;
        const dataArray = window.micDataArray;

        function getRMS() {
            analyser.getByteTimeDomainData(dataArray);
            let sum = 0;
            for (let i = 0; i < dataArray.length; i++) {
                const v = (dataArray[i] - 128) / 128;
                sum += v * v;
            }
            return Math.sqrt(sum / dataArray.length);
        }

        // ---- Calibrate baseline noise fresh for this segment ----
        const calibSamples = [];
        const calibStart = Date.now();
        while (Date.now() - calibStart < calibrationMs) {
            calibSamples.push(getRMS());
            await new Promise(r => setTimeout(r, 50));
        }
        const baseline = calibSamples.reduce((a, b) => a + b, 0) / calibSamples.length;
        const threshold = baseline + margin;
        console.log("Baseline:", baseline, "Threshold:", threshold);

        // ---- Record using the SAME persistent stream ----
        const recorder = new MediaRecorder(window.micStream);
        const chunks = [];
        recorder.ondataavailable = e => { if (e.data.size > 0) chunks.push(e.data); };
        recorder.start();

        const startTime = Date.now();
        let silenceStart = Date.now();

        return await new Promise((resolve, reject) => {
            function tick() {
                const rms = getRMS();
                const elapsed = (Date.now() - startTime) / 1000;

                if (rms > threshold) {
                    silenceStart = null;
                } else {
                    if (silenceStart === null) silenceStart = Date.now();
                    if ((Date.now() - silenceStart) / 1000 > silenceDuration) {
                        recorder.stop();
                        return;
                    }
                }

                if (elapsed > maxSeconds) { recorder.stop(); return; }
                requestAnimationFrame(tick);
            }

            recorder.onstop = () => {
                // NOTE: we do NOT stop the stream or close the context here —
                // it's persistent and reused for the next segment.
                const blob = new Blob(chunks, { type: recorder.mimeType });
                const reader = new FileReader();
                reader.onloadend = () => resolve(reader.result);
                reader.readAsDataURL(blob);
            };

            recorder.onerror = (e) => reject(e);

            tick();
        });
    }
    recordSegment
    """)

    display(js)

    data = eval_js(f"recordSegment({silence_duration}, {calibration_ms}, {max_seconds}, {margin})")

    audio_bytes = base64.b64decode(data.split(",")[1])

    webm_path = "/content/current_recording.webm"

    with open(webm_path, "wb") as f:
        f.write(audio_bytes)

    return webm_path

# %%
def convert_to_wav(webm_path):

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(
            orig_freq=sr,
            new_freq=16000
        )
        waveform = resampler(waveform)

    torchaudio.save(
        wav_path,
        waveform,
        16000
    )

    return wav_path

# %%
def transcribe_wav(wav_path):

    waveform, sr = torchaudio.load(wav_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    sr = 16000

    if waveform.shape[1] < int(0.3 * sr):
        return "", ""

    hindi_text = str(model(waveform, "hi", "rnnt")).strip()
    print("🇮🇳 Hindi:", hindi_text)

    if not hindi_text:
        print("⏭️ No speech detected — skipping translation")
        return "", ""

    english_text = translate(hindi_text, src_lang="hin_Deva", tgt_lang="eng_Latn")
    if isinstance(english_text, list):
        english_text = english_text[0]
    english_text = str(english_text).strip()

    print("🇬🇧 English:", english_text)

    return hindi_text, english_text

# %%
import traceback

recording_control = {"active": False}


def continuous_record_and_transcribe():

    hindi_history = ""
    english_history = ""

    try:
        print("Attempting mic init...")
        init_microphone()
        print("Mic init returned successfully.")
    except Exception as e:
        print("❌ MIC INIT FAILED:")
        traceback.print_exc()
        yield f"ERROR: {e}", "", None
        return

    try:
        while recording_control["active"]:
            print("\n🎤 Listening for a segment...")

            try:
                webm_path = record_from_browser_vad(
                    silence_duration=2.5,
                    calibration_ms=1000,
                    max_seconds=30,
                    margin=0.015
                )
            except Exception as e:
                print("❌ RECORDING FAILED:")
                traceback.print_exc()
                yield hindi_history + f"\n[ERROR: {e}]", english_history, None
                break

            print("Recorded:", webm_path, "Size:", os.path.getsize(webm_path), "bytes")

            wav_path = convert_to_wav(webm_path)
            hindi_text, english_text = transcribe_wav(wav_path)

            if hindi_text:
                hindi_history += hindi_text + "\n"
                english_history += english_text + "\n"
                yield hindi_history, english_history, wav_path
            else:
                print("(silence — listening again)")

    finally:
        try:
            cleanup_microphone()
        except Exception:
            traceback.print_exc()
        print("🛑 Stopped listening.")

# %%
def start_flag():
    recording_control["active"] = True

def stop_flag():
    recording_control["active"] = False




with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎤 Hindi Speech → English Translation (continuous)
        Speak, pause 2.5s to end a segment — it auto-translates and keeps listening.
        """
    )

    with gr.Row():
        start_button = gr.Button("▶️ Start Listening")
        stop_button = gr.Button("⏹️ Stop")

    transcription = gr.Textbox(label="🇮🇳 Hindi Transcript", lines=10)
    translation = gr.Textbox(label="🇬🇧 English Translation", lines=10)
    recorded_audio = gr.Audio(label="Last Segment", type="filepath")

    start_button.click(
        fn=start_flag, inputs=None, outputs=None
    ).then(
        fn=continuous_record_and_transcribe,
        inputs=None,
        outputs=[transcription, translation, recorded_audio]
    )

    stop_button.click(fn=stop_flag, inputs=None, outputs=None)

# demo.launch(debug=True)

# %% [markdown]
# ## Test#2
# Performed Well
#
# It produces transcripts -> translation -> isten -> produces transcripts -> translation
#
# I want: live Transcription -> Silence->Translation and so on

# %%
def init_microphone():
    js = Javascript("""
    if (typeof window.micReady === 'undefined') {
        window.micReady = false;   // only initialize once, don't clobber existing state
    }
    window.micDebugLog = [];

    function logMic(msg) {
        window.micDebugLog.push(msg);
        console.log("[MIC]", msg);
    }

    async function initMic() {
        try {
            if (window.micStream) {
                window.micReady = true;   // <-- THE FIX: restore the flag on reuse
                logMic("Already initialized, reusing.");
                return "already_ready|" + window.micDebugLog.join(" || ");
            }

            logMic("Requesting getUserMedia...");
            const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
            logMic("Got stream: " + stream.id);

            const audioContext = new AudioContext();
            logMic("AudioContext state: " + audioContext.state);

            if (audioContext.state === "suspended") {
                await audioContext.resume();
                logMic("After resume(), state: " + audioContext.state);
            }

            const source = audioContext.createMediaStreamSource(stream);
            const analyser = audioContext.createAnalyser();
            analyser.fftSize = 2048;
            source.connect(analyser);

            window.micStream = stream;
            window.micAudioContext = audioContext;
            window.micAnalyser = analyser;
            window.micDataArray = new Uint8Array(analyser.fftSize);
            window.micReady = true;

            logMic("Mic fully initialized.");
            return "ready|" + window.micDebugLog.join(" || ");

        } catch (err) {
            logMic("ERROR: " + err.name + ": " + err.message);
            return "error|" + err.name + ": " + err.message + "|" + window.micDebugLog.join(" || ");
        }
    }
    initMic
    """)
    display(js)
    result = eval_js("initMic()")
    print("🔍 RAW MIC INIT RESULT:", result)

    status = result.split("|")[0]
    print(f"🔍 Mic init status: {status}")

    if status == "error":
        raise RuntimeError(f"Mic init failed in browser: {result}")

    return result

# %%
def cleanup_microphone():
    js = Javascript("""
    function cleanupMic() {
        try {
            if (window.micStream) {
                window.micStream.getTracks().forEach(t => t.stop());
            }
            if (window.micAudioContext) {
                window.micAudioContext.close();
            }
            window.micStream = null;
            window.micAudioContext = null;
            window.micAnalyser = null;
            window.micReady = false;
            return "cleaned";
        } catch (err) {
            return "cleanup_error|" + err.message;
        }
    }
    cleanupMic
    """)
    display(js)
    result = eval_js("cleanupMic()")
    print("🔍 Mic cleanup result:", result)

# %%
def record_from_browser_vad(silence_duration=8, calibration_ms=1000, max_seconds=30, margin=0.015):
    js = Javascript("""
    async function recordSegment(silenceDuration, calibrationMs, maxSeconds, margin) {
        const log = [];
        function L(msg) { log.push(msg); console.log("[REC]", msg); }

        try {
            if (!window.micReady) {
                return "error|Mic not initialized|" + log.join(" || ");
            }

            const analyser = window.micAnalyser;
            const dataArray = window.micDataArray;

            function getRMS() {
                analyser.getByteTimeDomainData(dataArray);
                let sum = 0;
                for (let i = 0; i < dataArray.length; i++) {
                    const v = (dataArray[i] - 128) / 128;
                    sum += v * v;
                }
                return Math.sqrt(sum / dataArray.length);
            }

            L("Calibrating for " + calibrationMs + "ms...");
            const calibSamples = [];
            const calibStart = Date.now();
            while (Date.now() - calibStart < calibrationMs) {
                calibSamples.push(getRMS());
                await new Promise(r => setTimeout(r, 50));
            }
            const baseline = calibSamples.reduce((a, b) => a + b, 0) / calibSamples.length;
            const threshold = baseline + margin;
            L("Baseline=" + baseline.toFixed(4) + " Threshold=" + threshold.toFixed(4));

            if (window.micAudioContext.state !== "running") {
                L("WARNING: AudioContext state is " + window.micAudioContext.state + ", not running!");
            }

            const recorder = new MediaRecorder(window.micStream);
            const chunks = [];
            recorder.ondataavailable = e => { if (e.data.size > 0) chunks.push(e.data); };
            recorder.start();
            L("Recorder started, state=" + recorder.state);

            const startTime = Date.now();
            let silenceStart = Date.now();
            let maxRmsObserved = 0;

            return await new Promise((resolve, reject) => {
                function tick() {
                    const rms = getRMS();
                    if (rms > maxRmsObserved) maxRmsObserved = rms;
                    const elapsed = (Date.now() - startTime) / 1000;

                    if (rms > threshold) {
                        silenceStart = null;
                    } else {
                        if (silenceStart === null) silenceStart = Date.now();
                        if ((Date.now() - silenceStart) / 1000 > silenceDuration) {
                            L("Silence " + silenceDuration + "s reached. Stopping. Max RMS seen=" + maxRmsObserved.toFixed(4));
                            recorder.stop();
                            return;
                        }
                    }

                    if (elapsed > maxSeconds) {
                        L("Max seconds (" + maxSeconds + ") reached. Stopping.");
                        recorder.stop();
                        return;
                    }
                    requestAnimationFrame(tick);
                }

                recorder.onstop = () => {
                    L("Recorder stopped. Chunks: " + chunks.length);
                    const blob = new Blob(chunks, { type: recorder.mimeType });
                    const reader = new FileReader();
                    reader.onloadend = () => resolve("ok|" + reader.result + "|" + log.join(" || "));
                    reader.readAsDataURL(blob);
                };

                recorder.onerror = (e) => {
                    L("Recorder error: " + e.error);
                    resolve("error|Recorder error: " + e.error + "|" + log.join(" || "));
                };

                tick();
            });

        } catch (err) {
            L("EXCEPTION: " + err.name + ": " + err.message);
            return "error|" + err.name + ": " + err.message + "|" + log.join(" || ");
        }
    }
    recordSegment
    """)

    display(js)

    result = eval_js(f"recordSegment({silence_duration}, {calibration_ms}, {max_seconds}, {margin})")

    parts = result.split("|", 2)
    status = parts[0]

    if status == "error":
        error_msg = parts[1] if len(parts) > 1 else "unknown"
        log_trail = parts[2] if len(parts) > 2 else ""
        print(f"🔍 RECORDING ERROR: {error_msg}")
        print(f"🔍 JS log trail: {log_trail}")
        raise RuntimeError(f"Recording failed: {error_msg} | trail: {log_trail}")

    data_url = parts[1]
    log_trail = parts[2] if len(parts) > 2 else ""
    print(f"🔍 Recording JS log trail: {log_trail}")

    audio_bytes = base64.b64decode(data_url.split(",")[1])

    webm_path = "/content/current_recording.webm"
    with open(webm_path, "wb") as f:
        f.write(audio_bytes)

    return webm_path

# %%
def convert_to_wav(webm_path):
    print(f"🔍 Converting {webm_path}...")

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)
    print(f"🔍 Loaded waveform: shape={waveform.shape}, sr={sr}")

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    torchaudio.save(wav_path, waveform, 16000)
    print(f"🔍 Saved WAV: {wav_path}, duration={waveform.shape[1]/16000:.2f}s")

    return wav_path

# %%
def transcribe_wav(wav_path):
    print(f"🔍 Transcribing {wav_path}...")

    waveform, sr = torchaudio.load(wav_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    sr = 16000

    if waveform.shape[1] < int(0.3 * sr):
        print("🔍 Segment too short (<0.3s), skipping ASR.")
        return "", ""

    hindi_text = str(model(waveform, "hi", "rnnt")).strip()
    print("🇮🇳 Hindi:", repr(hindi_text))

    if not hindi_text:
        print("⏭️ No speech detected — skipping translation")
        return "", ""

    english_text = translate(hindi_text, src_lang="hin_Deva", tgt_lang="eng_Latn")
    if isinstance(english_text, list):
        english_text = english_text[0]
    english_text = str(english_text).strip()

    print("🇬🇧 English:", repr(english_text))

    return hindi_text, english_text

# %%
recording_control = {"active": False}


def continuous_record_and_transcribe():
    print("\n" + "="*50)
    print("🚀 continuous_record_and_transcribe() STARTED")
    print("="*50)

    hindi_history = ""
    english_history = ""

    try:
        print("Step 1: Initializing mic...")
        init_microphone()
        print("Step 1: ✅ Mic ready.")
    except Exception as e:
        print("❌ MIC INIT FAILED:")
        traceback.print_exc()
        yield f"[MIC INIT ERROR: {e}]", "", None
        return

    segment_num = 0

    try:
        while recording_control["active"]:
            segment_num += 1
            print(f"\n🎤 --- Segment {segment_num}: listening ---")

            try:
                webm_path = record_from_browser_vad(
                    silence_duration=2.5,
                    calibration_ms=1000,
                    max_seconds=30,
                    margin=0.015
                )
            except Exception as e:
                print(f"❌ SEGMENT {segment_num} RECORDING FAILED:")
                traceback.print_exc()
                yield (hindi_history + f"\n[SEGMENT {segment_num} ERROR: {e}]",
                       english_history, None)
                break

            size = os.path.getsize(webm_path)
            print(f"🔍 Segment {segment_num}: recorded {size} bytes")

            if size < 1000:
                print(f"⚠️ Segment {segment_num}: suspiciously small file, likely empty audio")

            try:
                wav_path = convert_to_wav(webm_path)
                hindi_text, english_text = transcribe_wav(wav_path)
            except Exception as e:
                print(f"❌ SEGMENT {segment_num} TRANSCRIPTION FAILED:")
                traceback.print_exc()
                yield (hindi_history + f"\n[TRANSCRIBE ERROR: {e}]",
                       english_history, None)
                continue

            if hindi_text:
                hindi_history += hindi_text + "\n"
                english_history += english_text + "\n"
                print(f"✅ Segment {segment_num}: yielding update")
                yield hindi_history, english_history, wav_path
            else:
                print(f"(Segment {segment_num}: silence, no update, looping)")

        print("🔁 Loop exited — recording_control['active'] is now False")

    finally:
        print("Cleaning up mic...")
        try:
            cleanup_microphone()
        except Exception:
            traceback.print_exc()
        print("🛑 continuous_record_and_transcribe() FULLY STOPPED")

# %%
def start_flag():
    print("▶️ Start button clicked — setting active=True")
    recording_control["active"] = True

def stop_flag():
    print("⏹️ Stop button clicked — setting active=False")
    recording_control["active"] = False

def test_mic():
    try:
        result = init_microphone()
        return f"✅ Mic initialized OK: {result}"
    except Exception as e:
        traceback.print_exc()
        return f"❌ Failed: {e}"


with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎤 Hindi Speech → English Translation (continuous)
        Speak, pause 2.5s to end a segment — it auto-translates and keeps listening.
        Watch the Colab cell output below the app for detailed logs.
        """
    )

    with gr.Row():
        start_button = gr.Button("▶️ Start Listening")
        stop_button = gr.Button("⏹️ Stop")

    transcription = gr.Textbox(label="🇮🇳 Hindi Transcript", lines=10)
    translation = gr.Textbox(label="🇬🇧 English Translation", lines=10)
    recorded_audio = gr.Audio(label="Last Segment", type="filepath")

    start_button.click(
        fn=start_flag, inputs=None, outputs=None
    ).then(
        fn=continuous_record_and_transcribe,
        inputs=None,
        outputs=[transcription, translation, recorded_audio]
    )

    stop_button.click(fn=stop_flag, inputs=None, outputs=None)

    test_button = gr.Button("🔧 Test Mic Init")
    test_output = gr.Textbox(label="Mic Test Result")
    test_button.click(fn=test_mic, inputs=None, outputs=test_output)

# demo.launch(debug=True,share=True)

# %% [markdown]
# # TTS
#
# Test #3 follows Test#2 but I have abandoned it for it is not required.

# %%
def init_microphone():
    js = Javascript("""
    if (typeof window.micReady === 'undefined') {
        window.micReady = false;
    }
    window.micDebugLog = [];

    function logMic(msg) {
        window.micDebugLog.push(msg);
        console.log("[MIC]", msg);
    }

    async function initMic() {
        try {
            if (window.micStream) {
                window.micReady = true;
                logMic("Already initialized, reusing.");
                return "already_ready|" + window.micDebugLog.join(" || ");
            }

            logMic("Requesting getUserMedia...");
            const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
            logMic("Got stream: " + stream.id);

            const audioContext = new AudioContext();
            logMic("AudioContext state: " + audioContext.state);

            if (audioContext.state === "suspended") {
                await audioContext.resume();
                logMic("After resume(), state: " + audioContext.state);
            }

            const source = audioContext.createMediaStreamSource(stream);
            const analyser = audioContext.createAnalyser();
            analyser.fftSize = 2048;
            source.connect(analyser);

            window.micStream = stream;
            window.micAudioContext = audioContext;
            window.micAnalyser = analyser;
            window.micDataArray = new Uint8Array(analyser.fftSize);
            window.micReady = true;

            logMic("Mic fully initialized.");
            return "ready|" + window.micDebugLog.join(" || ");

        } catch (err) {
            logMic("ERROR: " + err.name + ": " + err.message);
            return "error|" + err.name + ": " + err.message + "|" + window.micDebugLog.join(" || ");
        }
    }
    initMic
    """)
    display(js)
    result = eval_js("initMic()")
    print("🔍 RAW MIC INIT RESULT:", result)

    status = result.split("|")[0]
    print(f"🔍 Mic init status: {status}")

    if status == "error":
        raise RuntimeError(f"Mic init failed in browser: {result}")

    return result


def cleanup_microphone():
    js = Javascript("""
    function cleanupMic() {
        try {
            if (window.micStream) {
                window.micStream.getTracks().forEach(t => t.stop());
            }
            if (window.micAudioContext) {
                window.micAudioContext.close();
            }
            window.micStream = null;
            window.micAudioContext = null;
            window.micAnalyser = null;
            window.micReady = false;
            return "cleaned";
        } catch (err) {
            return "cleanup_error|" + err.message;
        }
    }
    cleanupMic
    """)
    display(js)
    result = eval_js("cleanupMic()")
    print("🔍 Mic cleanup result:", result)

# %%
def record_from_browser_vad(silence_duration=2.5, calibration_ms=1000, max_seconds=30, margin=0.015):
    js = Javascript("""
    async function recordSegment(silenceDuration, calibrationMs, maxSeconds, margin) {
        const log = [];
        function L(msg) { log.push(msg); console.log("[REC]", msg); }

        try {
            if (!window.micReady) {
                return "error|Mic not initialized|" + log.join(" || ");
            }

            const analyser = window.micAnalyser;
            const dataArray = window.micDataArray;

            function getRMS() {
                analyser.getByteTimeDomainData(dataArray);
                let sum = 0;
                for (let i = 0; i < dataArray.length; i++) {
                    const v = (dataArray[i] - 128) / 128;
                    sum += v * v;
                }
                return Math.sqrt(sum / dataArray.length);
            }

            L("Calibrating for " + calibrationMs + "ms...");
            const calibSamples = [];
            const calibStart = Date.now();
            while (Date.now() - calibStart < calibrationMs) {
                calibSamples.push(getRMS());
                await new Promise(r => setTimeout(r, 50));
            }
            const baseline = calibSamples.reduce((a, b) => a + b, 0) / calibSamples.length;
            const threshold = baseline + margin;
            L("Baseline=" + baseline.toFixed(4) + " Threshold=" + threshold.toFixed(4));

            if (window.micAudioContext.state !== "running") {
                L("WARNING: AudioContext state is " + window.micAudioContext.state + ", not running!");
            }

            const recorder = new MediaRecorder(window.micStream);
            const chunks = [];
            recorder.ondataavailable = e => { if (e.data.size > 0) chunks.push(e.data); };
            recorder.start();
            L("Recorder started, state=" + recorder.state);

            const startTime = Date.now();
            let silenceStart = Date.now();
            let maxRmsObserved = 0;

            return await new Promise((resolve, reject) => {
                function tick() {
                    const rms = getRMS();
                    if (rms > maxRmsObserved) maxRmsObserved = rms;
                    const elapsed = (Date.now() - startTime) / 1000;

                    if (rms > threshold) {
                        silenceStart = null;
                    } else {
                        if (silenceStart === null) silenceStart = Date.now();
                        if ((Date.now() - silenceStart) / 1000 > silenceDuration) {
                            L("Silence " + silenceDuration + "s reached. Stopping. Max RMS seen=" + maxRmsObserved.toFixed(4));
                            recorder.stop();
                            return;
                        }
                    }

                    if (elapsed > maxSeconds) {
                        L("Max seconds (" + maxSeconds + ") reached. Stopping.");
                        recorder.stop();
                        return;
                    }
                    requestAnimationFrame(tick);
                }

                recorder.onstop = () => {
                    L("Recorder stopped. Chunks: " + chunks.length);
                    const blob = new Blob(chunks, { type: recorder.mimeType });
                    const reader = new FileReader();
                    reader.onloadend = () => resolve("ok|" + reader.result + "|" + log.join(" || "));
                    reader.readAsDataURL(blob);
                };

                recorder.onerror = (e) => {
                    L("Recorder error: " + e.error);
                    resolve("error|Recorder error: " + e.error + "|" + log.join(" || "));
                };

                tick();
            });

        } catch (err) {
            L("EXCEPTION: " + err.name + ": " + err.message);
            return "error|" + err.name + ": " + err.message + "|" + log.join(" || ");
        }
    }
    recordSegment
    """)

    display(js)

    result = eval_js(f"recordSegment({silence_duration}, {calibration_ms}, {max_seconds}, {margin})")

    parts = result.split("|", 2)
    status = parts[0]

    if status == "error":
        error_msg = parts[1] if len(parts) > 1 else "unknown"
        log_trail = parts[2] if len(parts) > 2 else ""
        print(f"🔍 RECORDING ERROR: {error_msg}")
        print(f"🔍 JS log trail: {log_trail}")
        raise RuntimeError(f"Recording failed: {error_msg} | trail: {log_trail}")

    data_url = parts[1]
    log_trail = parts[2] if len(parts) > 2 else ""
    print(f"🔍 Recording JS log trail: {log_trail}")

    audio_bytes = base64.b64decode(data_url.split(",")[1])

    webm_path = "/content/current_recording.webm"
    with open(webm_path, "wb") as f:
        f.write(audio_bytes)

    return webm_path

# %%
def convert_to_wav(webm_path):
    print(f"🔍 Converting {webm_path}...")

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)
    print(f"🔍 Loaded waveform: shape={waveform.shape}, sr={sr}")

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    torchaudio.save(wav_path, waveform, 16000)
    print(f"🔍 Saved WAV: {wav_path}, duration={waveform.shape[1]/16000:.2f}s")

    return wav_path


def transcribe_wav(wav_path):
    print(f"🔍 Transcribing {wav_path}...")

    waveform, sr = torchaudio.load(wav_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    sr = 16000

    if waveform.shape[1] < int(0.3 * sr):
        print("🔍 Segment too short (<0.3s), skipping ASR.")
        return "", ""

    hindi_text = str(model(waveform, "hi", "rnnt")).strip()
    print("🇮🇳 Hindi:", repr(hindi_text))

    if not hindi_text:
        print("⏭️ No speech detected — skipping translation")
        return "", ""

    english_text = translate(hindi_text, src_lang="hin_Deva", tgt_lang="eng_Latn")
    if isinstance(english_text, list):
        english_text = english_text[0]
    english_text = str(english_text).strip()

    print("🇬🇧 English:", repr(english_text))

    return hindi_text, english_text

# %%
def convert_to_wav(webm_path):
    print(f"🔍 Converting {webm_path}...")

    wav_path = "/content/current_recording.wav"

    waveform, sr = torchaudio.load(webm_path)
    print(f"🔍 Loaded waveform: shape={waveform.shape}, sr={sr}")

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    torchaudio.save(wav_path, waveform, 16000)
    print(f"🔍 Saved WAV: {wav_path}, duration={waveform.shape[1]/16000:.2f}s")

    return wav_path


def transcribe_wav(wav_path):
    print(f"🔍 Transcribing {wav_path}...")

    waveform, sr = torchaudio.load(wav_path)

    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    if sr != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
        waveform = resampler(waveform)

    sr = 16000

    if waveform.shape[1] < int(0.3 * sr):
        print("🔍 Segment too short (<0.3s), skipping ASR.")
        return "", ""

    hindi_text = str(model(waveform, "hi", "rnnt")).strip()
    print("🇮🇳 Hindi:", repr(hindi_text))

    if not hindi_text:
        print("⏭️ No speech detected — skipping translation")
        return "", ""

    english_text = translate(hindi_text, src_lang="hin_Deva", tgt_lang="eng_Latn")
    if isinstance(english_text, list):
        english_text = english_text[0]
    english_text = str(english_text).strip()

    print("🇬🇧 English:", repr(english_text))

    return hindi_text, english_text

# %%
from chatterbox.tts import ChatterboxTTS

print("📥 Loading Chatterbox TTS weights...")
cbox = ChatterboxTTS.from_pretrained(device="cuda")
print(f"🔍 Chatterbox TTS loaded. Sample rate: {cbox.sr}")
# Out:
# 📥 Loading Chatterbox TTS weights...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5133/86591256.py in <cell line: 0>()
#       2
#       3 print("📥 Loading Chatterbox TTS weights...")
# ----> 4 cbox = ChatterboxTTS.from_pretrained(device="cuda")
#       5 print(f"🔍 Chatterbox TTS loaded. Sample rate: {cbox.sr}")
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/tts.py in from_pretrained(cls, device)
#     178             local_path = hf_hub_download(repo_id=REPO_ID, filename=fpath)
#     179
# --> 180         return cls.from_local(Path(local_path).parent, device)
#     181
#     182     def prepare_conditionals(self, wav_fpath, exaggeration=0.5):
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/tts.py in from_local(cls, ckpt_dir, device)
#     149         t3.to(device).eval()
#     150
# --> 151         s3gen = S3Gen()
#     152         s3gen.load_state_dict(
#     153             load_file(ckpt_dir / "s3gen.safetensors"), strict=False
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/models/s3gen/s3gen.py in __init__(self, meanflow)
#     240
#     241     def __init__(self, meanflow=False):
# --> 242         super().__init__(meanflow)
#     243
#     244         f0_predictor = ConvRNNF0Predictor()
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/models/s3gen/s3gen.py in __init__(self, meanflow)
#      62         self.meanflow = meanflow
#      63
# ---> 64         encoder = UpsampleConformerEncoder(
#      65             output_size=512,
#      66             attention_heads=8,
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/models/s3gen/transformer/upsample_encoder.py in __init__(self, input_size, output_size, attention_heads, linear_units, num_blocks, dropout_rate, positional_dropout_rate, attention_dropout_rate, input_layer, pos_enc_layer_type, normalize_before, static_chunk_size, use_dynamic_chunk, global_cmvn, use_dynamic_left_chunk, positionwise_conv_kernel_size, macaron_style, selfattention_layer_type, activation_type, use_cnn_module, cnn_module_kernel, causal, cnn_module_norm, key_bias, gradient_checkpointing)
#     194         convolution_layer_args = (output_size, cnn_module_kernel, activation,
#     195                                   cnn_module_norm, causal)
# --> 196         self.pre_lookahead_layer = PreLookaheadLayer(channels=512, pre_lookahead_len=3)
#     197         self.encoders = torch.nn.ModuleList([
#     198             ConformerEncoderLayer(
#
# /usr/local/lib/python3.13/dist-packages/chatterbox/models/s3gen/transformer/upsample_encoder.py in __init__(self, channels, pre_lookahead_len)
#      69         self.channels = channels
#      70         self.pre_lookahead_len = pre_lookahead_len
# ---> 71         self.conv1 = nn.Conv1d(
#      72             channels, channels,
#      73             kernel_size=pre_lookahead_len + 1,
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     340         padding_ = padding if isinstance(padding, str) else _single(padding)
#     341         dilation_ = _single(dilation)
# --> 342         super().__init__(
#     343             in_channels,
#     344             out_channels,
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     174             self.register_parameter("bias", None)
#     175
# --> 176         self.reset_parameters()
#     177
#     178     def reset_parameters(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/conv.py in reset_parameters(self)
#     180         # uniform(-1/sqrt(k), 1/sqrt(k)), where k = weight.size(1) * prod(*kernel_size)
#     181         # For more details see: https://github.com/pytorch/pytorch/issues/15314#issuecomment-477448573
# --> 182         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#     183         if self.bias is not None:
#     184             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/init.py in kaiming_uniform_(tensor, a, mode, nonlinearity, generator)
#     516     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     517     with torch.no_grad():
# --> 518         return tensor.uniform_(-bound, bound, generator=generator)
#     519
#     520
#
# KeyboardInterrupt:

# %%
def speak_text(text, out_path="/content/tts_output.wav"):
    if not text.strip():
        return None, 0.0

    print(f"🔍 TTS generating for: {text[:60]}...")

    speech = cbox.generate(text=text)

    torchaudio.save(out_path, speech, cbox.sr)

    duration = speech.shape[-1] / cbox.sr
    print(f"🔍 TTS saved: {out_path}, duration={duration:.2f}s")

    return out_path, duration

# %%
# recording_control = {"active": False}


# def continuous_record_and_transcribe():
#     print("\n" + "="*50)
#     print("🚀 continuous_record_and_transcribe() STARTED")
#     print("="*50)

#     hindi_history = ""
#     english_history = ""

#     try:
#         print("Step 1: Initializing mic...")
#         init_microphone()
#         print("Step 1: ✅ Mic ready.")
#     except Exception as e:
#         print("❌ MIC INIT FAILED:")
#         traceback.print_exc()
#         yield f"[MIC INIT ERROR: {e}]", "", None, None
#         return

#     segment_num = 0

#     try:
#         while recording_control["active"]:
#             segment_num += 1
#             print(f"\n🎤 --- Segment {segment_num}: listening ---")

#             try:
#                 webm_path = record_from_browser_vad(
#                     silence_duration=2.5,
#                     calibration_ms=1000,
#                     max_seconds=30,
#                     margin=0.015
#                 )
#             except Exception as e:
#                 print(f"❌ SEGMENT {segment_num} RECORDING FAILED:")
#                 traceback.print_exc()
#                 yield (hindi_history + f"\n[SEGMENT {segment_num} ERROR: {e}]",
#                        english_history, None, None)
#                 break

#             size = os.path.getsize(webm_path)
#             print(f"🔍 Segment {segment_num}: recorded {size} bytes")

#             try:
#                 wav_path = convert_to_wav(webm_path)
#                 hindi_text, english_text = transcribe_wav(wav_path)
#             except Exception as e:
#                 print(f"❌ SEGMENT {segment_num} TRANSCRIPTION FAILED:")
#                 traceback.print_exc()
#                 yield (hindi_history + f"\n[TRANSCRIBE ERROR: {e}]",
#                        english_history, None, None)
#                 continue

#             if hindi_text:
#                 hindi_history += hindi_text + "\n"
#                 english_history += english_text + "\n"

#                 # ---- NEW: TTS step (Silence -> Translation -> TTS) ----
#                 try:
#                     tts_path, tts_duration = speak_text(english_text)
#                 except Exception as e:
#                     print(f"❌ SEGMENT {segment_num} TTS FAILED:")
#                     traceback.print_exc()
#                     tts_path, tts_duration = None, 0.0

#                 print(f"✅ Segment {segment_num}: yielding update (with TTS)")
#                 yield hindi_history, english_history, wav_path, tts_path

#                 # Pause for TTS playback duration so the mic doesn't hear its own output
#                 if tts_duration > 0:
#                     wait_time = tts_duration + 0.5
#                     print(f"🔍 Pausing {wait_time:.1f}s for TTS playback before resuming listening...")
#                     time.sleep(wait_time)
#                 # ---------------------------------------------------------

#             else:
#                 print(f"(Segment {segment_num}: silence, no update, looping)")

#         print("🔁 Loop exited — recording_control['active'] is now False")

#     finally:
#         print("Cleaning up mic...")
#         try:
#             cleanup_microphone()
#         except Exception:
#             traceback.print_exc()
#         print("🛑 continuous_record_and_transcribe() FULLY STOPPED")

# %%
import os
import time
import traceback

recording_control = {"active": False}

def continuous_record_and_transcribe():
    print("\n" + "="*50)
    print("🚀 continuous_record_and_transcribe() STARTED")
    print("="*50)

    hindi_history = ""
    english_history = ""

    try:
        print("Step 1: Initializing mic...")
        init_microphone()
        print("Step 1: ✅ Mic ready.")
    except Exception as e:
        print("❌ MIC INIT FAILED:")
        traceback.print_exc()
        yield f"[MIC INIT ERROR: {e}]", "", None, None
        return

    segment_num = 0

    try:
        while recording_control["active"]:
            segment_num += 1
            print(f"\n🎤 --- Segment {segment_num}: listening ---")

            try:
                webm_path = record_from_browser_vad(
                    silence_duration=2.5,
                    calibration_ms=1000,
                    max_seconds=30,
                    margin=0.015
                )
            except Exception as e:
                print(f"❌ SEGMENT {segment_num} RECORDING FAILED:")
                traceback.print_exc()
                yield (hindi_history + f"\n[SEGMENT {segment_num} ERROR: {e}]",
                       english_history, None, None)
                break

            # Safety check: Ensure webm_path is a valid file, not a directory
            if not webm_path or os.path.isdir(webm_path) or not os.path.exists(webm_path):
                print(f"⚠️ Segment {segment_num}: Invalid webm path generated.")
                yield (hindi_history or "Listening...", english_history or "Waiting for speech...", None, None)
                continue

            size = os.path.getsize(webm_path)
            print(f"🔍 Segment {segment_num}: recorded {size} bytes")

            try:
                wav_path = convert_to_wav(webm_path)
                hindi_text, english_text = transcribe_wav(wav_path)
            except Exception as e:
                print(f"❌ SEGMENT {segment_num} TRANSCRIPTION FAILED:")
                traceback.print_exc()
                yield (hindi_history + f"\n[TRANSCRIBE ERROR: {e}]",
                       english_history, None, None)
                continue

            # Double-check that wav_path is an actual file before serving it to Gradio
            safe_wav_path = wav_path if (wav_path and os.path.exists(wav_path) and not os.path.isdir(wav_path)) else None

            if hindi_text.strip():
                hindi_history += hindi_text + "\n"
                english_history += english_text + "\n"

                # ---- TTS step (Silence -> Translation -> TTS) ----
                try:
                    tts_path, tts_duration = speak_text(english_text)
                except Exception as e:
                    print(f"❌ SEGMENT {segment_num} TTS FAILED:")
                    traceback.print_exc()
                    tts_path, tts_duration = None, 0.0

                # Double-check that tts_path is an actual file before serving it to Gradio
                safe_tts_path = tts_path if (tts_path and os.path.exists(tts_path) and not os.path.isdir(tts_path)) else None

                print(f"✅ Segment {segment_num}: yielding update (with TTS)")
                yield hindi_history, english_history, safe_wav_path, safe_tts_path

                # Pause for TTS playback duration so the mic doesn't hear its own output
                if tts_duration > 0:
                    wait_time = tts_duration + 0.5
                    print(f"🔍 Pausing {wait_time:.1f}s for TTS playback before resuming listening...")
                    time.sleep(wait_time)

            else:
                print(f"(Segment {segment_num}: silence, no update, looping safely)")
                # 🎯 THE CRITICAL FIX: Yield to Gradio even on silence so the UI loop stays active
                # and doesn't pass unhandled directory fallback states!
                yield (
                    hindi_history if hindi_history else "Listening...",
                    english_history if english_history else "Waiting for speech...",
                    None,
                    None
                )

        print("🔁 Loop exited — recording_control['active'] is now False")

    finally:
        print("Cleaning up mic...")
        try:
            cleanup_microphone()
        except Exception:
            traceback.print_exc()
        print("🛑 continuous_record_and_transcribe() FULLY STOPPED")

# %%
def start_flag():
    print("▶️ Start button clicked — setting active=True")
    recording_control["active"] = True

def stop_flag():
    print("⏹️ Stop button clicked — setting active=False")
    recording_control["active"] = False


with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🎤 Hindi Speech → English Translation → 🔊 Spoken Translation
        Speak, pause 2.5s to end a segment — translation plays back automatically, then it keeps listening.
        """
    )

    with gr.Row():
        start_button = gr.Button("▶️ Start Listening")
        stop_button = gr.Button("⏹️ Stop")

    transcription = gr.Textbox(label="🇮🇳 Hindi Transcript", lines=10)
    translation = gr.Textbox(label="🇬🇧 English Translation", lines=10)
    recorded_audio = gr.Audio(label="Last Segment (your voice)", type="filepath")
    tts_audio = gr.Audio(label="🔊 Spoken Translation", type="filepath", autoplay=True)

    start_button.click(
        fn=start_flag, inputs=None, outputs=None
    ).then(
        fn=continuous_record_and_transcribe,
        inputs=None,
        outputs=[transcription, translation, recorded_audio, tts_audio]
    )

    stop_button.click(fn=stop_flag, inputs=None, outputs=None)

demo.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://614ee1b92d48544796.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://614ee1b92d48544796.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 🇮🇳 Hindi: 'दीदी सुन दीदी ये मेरी है ये मेरी जिम्मेदारी थी कि'
# /usr/lib/python3.13/contextlib.py:109: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# hin_Deva - eng_Latn
# 🇬🇧 English: 'Didi, listen, didi, this is mine. It was my responsibility.'
# 🔍 TTS generating for: Didi, listen, didi, this is mine. It was my responsibility....
# Sampling:   7%|▋         | 72/1000 [00:02<00:32, 28.94it/s]
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://614ee1b92d48544796.gradio.live

# %% [markdown]
# #Persistency

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
envpath='/content/drive/MyDrive/TTS_ASR'
os.makedirs(envpath,exist_ok=True)

# %%
site_packages = site.getsitepackages()[0]

# %%
import os
import shutil
import importlib.metadata
from google.colab import drive

envpath = '/content/drive/MyDrive/TTS_ASR'
os.makedirs(envpath, exist_ok=True)

final_archive = os.path.join(envpath, 'tts_env_py313.tar.gz')
local_archive = '/content/tts_env_py313.tar.gz'
dist_path = '/usr/local/lib/python3.13/dist-packages'
print("Paths Defined")
# 2. Package list
target_pkgs = {
    'coqui-tts', 'anyascii', 'coqpit-config', 'coqui-tts-trainer',
    'ko-speech-tools', 'monotonic-alignment-search', 'num2words',
    'pysbd', 'docopt', 'torch', 'torchvision', 'torchaudio',
    'triton', 'nvidia-cublas-cu12', 'nvidia-cuda-cupti-cu12',
    'nvidia-cuda-nvrtc-cu12', 'nvidia-cuda-runtime-cu12', 'nvidia-cudnn-cu12',
    'nvidia-cufft-cu12', 'nvidia-curand-cu12', 'nvidia-cusolver-cu12',
    'nvidia-cusparse-cu12', 'nvidia-cusparselt-cu12', 'nvidia-nccl-cu12',
    'nvidia-nvjitlink-cu12', 'nvidia-nvtx-cu12', 'numpy', 'sympy',
    'mpmath', 'chatterbox-tts', 'gradio'
}

# 3. Resolve exact files/folders
files_to_pack = set()
for pkg in target_pkgs:
    try:
        dist = importlib.metadata.distribution(pkg)
        if dist.files:
            for file_path in dist.files:
                top_part = file_path.parts[0]
                if os.path.exists(os.path.join(dist_path, top_part)):
                    files_to_pack.add(top_part)
    except importlib.metadata.PackageNotFoundError:
        pass

# Save list of items to a file for system tar
with open('/content/pack_list.txt', 'w') as f:
    for item in sorted(files_to_pack):
        f.write(f"{item}\n")

print(f"Discovered {len(files_to_pack)} items. Compressing locally on SSD...")

# 4. Use system-level multi-threaded tar locally (much faster than Python tarfile)
# !tar -czf {local_archive} -C {dist_path} -T /content/pack_list.txt

# 5. Move finished archive to Drive as one single atomic transfer
print("Archive created locally. Uploading to Drive...")
shutil.copy2(local_archive, final_archive)

# Clean up local archive to free Colab disk space
os.remove(local_archive)
os.remove('/content/pack_list.txt')

print(f"\nCompleted successfully! File saved at: {final_archive}")
# Out:
# Paths Defined
# Discovered 61 items. Compressing locally on SSD...
# tar: Removing leading `..' from member names
# tar: Removing leading `../' from member names
# tar: Removing leading `../' from hard link targets
